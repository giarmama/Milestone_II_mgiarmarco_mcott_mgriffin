# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import TruncatedSVD, PCA
from scipy.sparse import hstack

# %%
data = pd.read_csv('data/final.csv', dtype={1: str})

# %%
states = ['CHI', 'NYC']
results = {}

for state in states:
    # Check each state individually
    df_state = data[data['state'] == state].copy().dropna().reset_index(drop=True)

    # Define columns
    exclude_cols = ['date', 'state', 'daily_ridership', 'unit_id', 'mode']
    feature_cols = [col for col in df_state.columns if col not in exclude_cols]

    # Truncated SVD on unit_id
    ohe_unit = OneHotEncoder(sparse_output=True, handle_unknown='ignore')
    unit_sparse = ohe_unit.fit_transform(df_state[['unit_id']])
    svd = TruncatedSVD(n_components=20, random_state=42)
    unit_svd = svd.fit_transform(unit_sparse)
    unit_svd_df = pd.DataFrame(unit_svd, index=df_state.index, columns=[f'unit_svd_{i+1}' for i in range(20)])

    # One-hot encode mode
    mode_dummies = pd.get_dummies(df_state['mode'], prefix='mode', drop_first=True)

    # Scale weather + AQI features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df_state[feature_cols])
    scaled_df = pd.DataFrame(X_scaled, index=df_state.index, columns=feature_cols)

    # Combine unit SVD, one-hot, and scaled features
    X_final = pd.concat([unit_svd_df, mode_dummies.reset_index(drop=True), scaled_df], axis=1)

    # Run PCA
    pca = PCA()
    X_pca = pca.fit_transform(X_final)

    explained_var = pd.DataFrame({
        'Component': [f'PC{i+1}' for i in range(pca.n_components_)],
        'Explained Variance Ratio': pca.explained_variance_ratio_
    })

    loadings = pd.DataFrame(
        pca.components_.T,
        index=X_final.columns,
        columns=[f'PC{i+1}' for i in range(pca.n_components_)]
    )

    # Store results
    results[state] = {
        'X_pca': X_pca,
        'explained_var': explained_var,
        'loadings': loadings,
        'features': X_final
    }
# Out:
# unit_svd_1                     0
# unit_svd_2                     0
# unit_svd_3                     0
# unit_svd_4                     0
# unit_svd_5                     0
#                               ..
# us_aqi_sulphur_dioxide_mean    0
# us_aqi_min_lag                 0
# us_aqi_max_lag                 0
# us_aqi_mean_lag                0
# is_weekend                     0
# Length: 63, dtype: int64
# unit_svd_1                     0
# unit_svd_2                     0
# unit_svd_3                     0
# unit_svd_4                     0
# unit_svd_5                     0
#                               ..
# us_aqi_sulphur_dioxide_mean    0
# us_aqi_min_lag                 0
# us_aqi_max_lag                 0
# us_aqi_mean_lag                0
# is_weekend                     0
# Length: 63, dtype: int64

# %%
results['CHI']['explained_var'].head(10)
# Out:
#   Component  Explained Variance Ratio
# 0       PC1                  0.298562
# 1       PC2                  0.163064
# 2       PC3                  0.079444
# 3       PC4                  0.072997
# 4       PC5                  0.041838
# 5       PC6                  0.040887
# 6       PC7                  0.035113
# 7       PC8                  0.034410
# 8       PC9                  0.028542
# 9      PC10                  0.023702

# %%
pcs = ['PC1', 'PC2', 'PC3']
states = ['CHI', 'NYC']

for state in states:
    for pc in pcs:
        print(state,pc)
        loadings = results[state]['loadings'][pc]
        top_features = loadings.abs().sort_values(ascending=False).head(20)
        print(top_features)
# Out:
# CHI PC1
# us_aqi_pm2_5_mean               0.260497
# us_aqi_pm10_mean                0.258135
# us_aqi_pm2_5_min                0.254400
# us_aqi_pm10_min                 0.252696
# us_aqi_pm2_5_max                0.249275
# us_aqi_pm10_max                 0.248251
# us_aqi_mean                     0.231401
# us_aqi_max                      0.229205
# us_aqi_min                      0.218041
# us_aqi_max_lag                  0.187678
# us_aqi_min_lag                  0.185465
# us_aqi_mean_lag                 0.184984
# us_aqi_carbon_monoxide_mean     0.167343
# apparent_temperature_max        0.164678
# us_aqi_ozone_max                0.164581
# us_aqi_carbon_monoxide_max      0.157733
# apparent_temperature_min        0.157426
# apparent_temperature_max_lag    0.150351
# wind_speed_10m_min              0.142728
# us_aqi_carbon_monoxide_min      0.138680
# Name: PC1, dtype: float64
# CHI PC2
# us_aqi_ozone_min                0.306225
# us_aqi_ozone_mean               0.293748
# us_aqi_nitrogen_dioxide_mean    0.288402
# us_aqi_nitrogen_dioxide_min     0.283554
# apparent_temperature_max_lag    0.260301
# apparent_temperature_min_lag    0.256916
# apparent_temperature_min        0.239040
# us_aqi_nitrogen_dioxide_max     0.232097
# us_aqi_sulphur_dioxide_mean     0.230908
# apparent_temperature_max        0.230693
# us_aqi_ozone_max                0.223901
# us_aqi_sulphur_dioxide_min      0.215522
# us_aqi_carbon_monoxide_max      0.198358
# us_aqi_sulphur_dioxide_max      0.190450
# us_aqi_carbon_monoxide_mean     0.186378
# us_aqi_max_lag                  0.124612
# wind_speed_10m_max              0.118484
# us_aqi_carbon_monoxide_min      0.117929
# wind_speed_10m_mean             0.107797
# us_aqi_mean_lag                 0.091819
# Name: PC2, dtype: float64
# CHI PC3
# relative_humidity_2m_mean       0.486422
# relative_humidity_2m_min        0.441604
# relative_humidity_2m_max        0.421771
# rain_sum                        0.278178
# rain_max                        0.217718
# snowfall_sum                    0.207095
# snowfall_max                    0.197208
# us_aqi_sulphur_dioxide_min      0.170330
# us_aqi_sulphur_dioxide_mean     0.142074
# wind_direction_10m_max          0.122709
# apparent_temperature_max        0.121050
# us_aqi_nitrogen_dioxide_max     0.104406
# us_aqi_sulphur_dioxide_max      0.101529
# us_aqi_max_lag                  0.091427
# wind_direction_10m_min          0.090881
# wind_speed_10m_mean             0.089737
# us_aqi_ozone_mean               0.087529
# wind_speed_10m_max              0.086394
# us_aqi_ozone_min                0.079106
# us_aqi_nitrogen_dioxide_mean    0.069032
# Name: PC3, dtype: float64
# NYC PC1
# us_aqi_pm2_5_mean               0.257090
# us_aqi_pm10_mean                0.252617
# us_aqi_pm2_5_min                0.245398
# us_aqi_pm10_min                 0.240828
# us_aqi_pm2_5_max                0.239929
# us_aqi_pm10_max                 0.238087
# us_aqi_mean                     0.226262
# us_aqi_min                      0.205003
# us_aqi_max                      0.202466
# us_aqi_carbon_monoxide_mean     0.192108
# us_aqi_carbon_monoxide_min      0.178516
# us_aqi_carbon_monoxide_max      0.176219
# wind_speed_10m_mean             0.174244
# us_aqi_nitrogen_dioxide_mean    0.163125
# us_aqi_sulphur_dioxide_mean     0.160728
# wind_speed_10m_min              0.156407
# us_aqi_sulphur_dioxide_max      0.150844
# us_aqi_mean_lag                 0.149619
# us_aqi_max_lag                  0.148668
# us_aqi_sulphur_dioxide_min      0.140811
# Name: PC1, dtype: float64
# NYC PC2
# us_aqi_ozone_mean               0.300517
# apparent_temperature_min_lag    0.275496
# apparent_temperature_max_lag    0.272801
# us_aqi_ozone_min                0.265309
# apparent_temperature_min        0.254064
# us_aqi_nitrogen_dioxide_min     0.252624
# us_aqi_ozone_max                0.250041
# apparent_temperature_max        0.248611
# us_aqi_nitrogen_dioxide_mean    0.247378
# us_aqi_sulphur_dioxide_max      0.220218
# us_aqi_sulphur_dioxide_mean     0.209635
# us_aqi_max_lag                  0.187652
# us_aqi_carbon_monoxide_mean     0.186338
# us_aqi_carbon_monoxide_max      0.185463
# us_aqi_nitrogen_dioxide_max     0.157647
# us_aqi_sulphur_dioxide_min      0.157480
# us_aqi_mean_lag                 0.140785
# us_aqi_min_lag                  0.137504
# us_aqi_carbon_monoxide_min      0.135247
# us_aqi_max                      0.124325
# Name: PC2, dtype: float64
# NYC PC3
# relative_humidity_2m_mean      0.443482
# relative_humidity_2m_min       0.421517
# relative_humidity_2m_max       0.382324
# wind_direction_10m_mean        0.323490
# rain_sum                       0.316471
# wind_direction_10m_max         0.250840
# rain_max                       0.247437
# wind_direction_10m_min         0.189048
# us_aqi_nitrogen_dioxide_max    0.134615
# snowfall_max                   0.112964
# snowfall_sum                   0.103727
# us_aqi_ozone_max               0.091575
# us_aqi_nitrogen_dioxide_min    0.091134
# us_aqi_ozone_mean              0.085260
# wind_speed_10m_min             0.077578
# wind_speed_10m_mean            0.069408
# us_aqi_min                     0.065406
# us_aqi_carbon_monoxide_mean    0.062894
# us_aqi_mean                    0.059224
# us_aqi_carbon_monoxide_max     0.055798
# Name: PC3, dtype: float64
