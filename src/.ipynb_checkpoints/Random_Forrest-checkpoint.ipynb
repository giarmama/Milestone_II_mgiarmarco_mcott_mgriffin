# %%
import pandas as pd
import numpy as np
import os
import json
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import root_mean_squared_error, r2_score, make_scorer
import matplotlib.pyplot as plt
# Out:
# C:\Users\Mickey\anaconda3\Lib\site-packages\sklearn\utils\__init__.py:16: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.2)
#   from scipy.sparse import issparse

# %%
NYC_df = pd.read_csv('data/NYC_trunc.csv',low_memory=False)
CHI_df = pd.read_csv('data/CHI_trunc.csv',low_memory=False)

# %%
def randforr(df, tune=False, cv_folds=5):
    drop_cols = ['state', 'unit_id', 'mode']
    df = df.drop(columns=[col for col in drop_cols if col in df.columns], errors='ignore')

    y = df['daily_ridership']
    X = df.drop(columns=['daily_ridership', 'date'])

    rf = RandomForestRegressor(random_state=27, n_jobs=-1)

    #GridsearchCV tuning 
    param_grid = {
        'n_estimators': [50, 100, 150, 200],
        'max_depth': [10, 20, None],
        'min_samples_split': [2, 5, 10, 25],
        'min_samples_leaf': [1, 2, 5, 10]
    }
    grid_search = GridSearchCV(rf, param_grid, cv=cv_folds, scoring='r2', n_jobs=-1)
    grid_search.fit(X, y)
    rf = grid_search.best_estimator_
    print("Best Parameters:", grid_search.best_params_)

    # Cross-validation scores
    kf = KFold(n_splits=cv_folds, shuffle=True, random_state=27)
    r2_scores = []
    rmse_scores = []

    for train_idx, test_idx in kf.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        r2_scores.append(r2_score(y_test, y_pred))
        rmse_scores.append(root_mean_squared_error(y_test, y_pred))

    print("R² scores (CV):", r2_scores)
    print("RMSE scores (CV):", rmse_scores)
    print(f"\nMean R²: {np.mean(r2_scores):.4f} ± {np.std(r2_scores):.4f}")
    print(f"Mean RMSE: {np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}")

    # train/test evaluation
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)

    rmse = root_mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    importances = rf.feature_importances_
    feat_names = X_train.columns
    sorted_idx = np.argsort(importances)[::-1]
    plt.barh(range(10), importances[sorted_idx[:10]])
    plt.yticks(range(10), feat_names[sorted_idx[:10]])
    plt.xlabel("Feature Importance")
    plt.title("Top 10 Important Features")
    plt.gca().invert_yaxis()
    plt.show()

    print(f"Random Forest RMSE: {rmse:.2f}")
    print(f"Random Forest R²: {r2:.4f}")

# %%
def randforr(df, cv_folds=5):
    for mode_val in df['mode'].dropna().unique():
              
        df_mode = df[df['mode'] == mode_val].copy()
        drop_cols = ['state', 'unit_id', 'mode']
        df_mode = df_mode.drop(columns=[col for col in drop_cols if col in df_mode.columns], errors='ignore')

        y = df_mode['daily_ridership']
        X = df_mode.drop(columns=['daily_ridership', 'date'])

        # GridSearchCV
        rf = RandomForestRegressor(random_state=27, n_jobs=-1)
        param_grid = {
            'n_estimators': [50, 100, 150, 200],
            'max_depth': [10, 20, None],
            'min_samples_split': [2, 5, 10, 25],
            'min_samples_leaf': [1, 2, 5, 10]
        }
        grid_search = GridSearchCV(rf, param_grid, cv=cv_folds, scoring='r2', n_jobs=-1)
        grid_search.fit(X, y)
        rf = grid_search.best_estimator_
        print("Best Parameters:", grid_search.best_params_)

        # Cross-val scoring
        kf = KFold(n_splits=cv_folds, shuffle=True, random_state=27)
        r2_scores = []
        rmse_scores = []

        for train_idx, test_idx in kf.split(X, y):
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

            rf.fit(X_train, y_train)
            y_pred = rf.predict(X_test)

            r2_scores.append(r2_score(y_test, y_pred))
            rmse_scores.append(root_mean_squared_error(y_test, y_pred))

        print("R² scores (CV):", r2_scores)
        print("RMSE scores (CV):", rmse_scores)
        print(f"Mean R²: {np.mean(r2_scores):.4f} ± {np.std(r2_scores):.4f}")
        print(f"Mean RMSE: {np.mean(rmse_scores):.2f} ± {np.std(rmse_scores):.2f}")

        # Evaluation with best params
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_test)

        rmse = root_mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        importances = rf.feature_importances_
        feat_names = X_train.columns
        sorted_idx = np.argsort(importances)[::-1]
        plt.barh(range(10), importances[sorted_idx[:10]])
        plt.yticks(range(10), feat_names[sorted_idx[:10]])
        plt.xlabel("Feature Importance")
        plt.title(f"Top 10 Important Features ({mode_val})")
        plt.gca().invert_yaxis()
        plt.show()

        print(f"Random Forest for mode: {mode_val}")
        print(f"RMSE: {rmse:.2f}")
        print(f"R²: {r2:.4f}")

# %%
randforr(CHI_df)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 25, 'n_estimators': 50}
# R² scores (CV): [0.4802491832659276, 0.4544012698363954, 0.5290568590468459, 0.5584193433817164, 0.5053108279901277]
# RMSE scores (CV): [504.9526781857839, 478.56350410959834, 476.34592349706605, 434.16364237600294, 459.0780317595256]
# Mean R²: 0.5055 ± 0.0363
# Mean RMSE: 470.62 ± 23.40
# Random Forest for mode: bus
# RMSE: 500.94
# R²: 0.4885
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# R² scores (CV): [0.6536599513674193, 0.6925772773190941, 0.7449348001280038, 0.720660652323406, 0.7240501412155302]
# RMSE scores (CV): [302.1120170003228, 273.2603126479846, 259.44844502451156, 260.04622299847125, 256.19452731503395]
# Mean R²: 0.7072 ± 0.0315
# Mean RMSE: 270.21 ± 16.99
# Random Forest for mode: train
# RMSE: 303.92
# R²: 0.6495

# %%
# Drop top 1 feature
df_no_weekend = CHI_df.drop(columns=['is_weekend'])
randforr(df_no_weekend)

# Drop top 2 features
df_no_weekend_holiday = CHI_df.drop(columns=['is_weekend', 'is_holiday'])
randforr(df_no_weekend_holiday)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 25, 'n_estimators': 200}
# R² scores (CV): [0.19306995245762915, 0.20867656729545037, 0.2987439759776691, 0.3435555713397024, 0.2683036449298075]
# RMSE scores (CV): [629.1743853331637, 576.3415277142602, 581.2681373674185, 529.3554819856085, 558.3233030014677]
# Mean R²: 0.2625 ± 0.0559
# Mean RMSE: 574.89 ± 32.67
# Random Forest for mode: bus
# RMSE: 627.09
# R²: 0.1984
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 25, 'n_estimators': 200}
# R² scores (CV): [0.08365035932510823, 0.12741032079407943, 0.30665001857301677, 0.19410211188927973, 0.16586702446153956]
# RMSE scores (CV): [491.4136894064584, 460.3769957868723, 427.7615272701451, 441.6970531858514, 445.4227608436132]
# Mean R²: 0.1755 ± 0.0754
# Mean RMSE: 453.33 ± 21.69
# Random Forest for mode: train
# RMSE: 489.52
# R²: 0.0907
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 50}
# R² scores (CV): [0.18938355782910965, 0.1871672535128479, 0.2825723370535669, 0.3332414960175266, 0.254109408356207]
# RMSE scores (CV): [630.6099138119931, 584.121909242233, 587.9322375899031, 533.4978988724853, 563.7127702514787]
# Mean R²: 0.2493 ± 0.0559
# Mean RMSE: 579.97 ± 31.84
# Random Forest for mode: bus
# RMSE: 638.53
# R²: 0.1689
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 25, 'n_estimators': 200}
# R² scores (CV): [0.08776922792047948, 0.1097969434102436, 0.30178618730151907, 0.1797256488429232, 0.17955871220104824]
# RMSE scores (CV): [490.30802627976203, 465.00017804690407, 429.25927294196237, 445.6193686405752, 441.751989493889]
# Mean R²: 0.1717 ± 0.0747
# Mean RMSE: 454.39 ± 21.31
# Random Forest for mode: train
# RMSE: 486.99
# R²: 0.1001

# %%
randforr(NYC_df)
# Out:
# Best Parameters: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 25, 'n_estimators': 150}
# R² scores (CV): [0.83461190677387, 0.8535982317624524, 0.8751722271341408, 0.8561282372839453, 0.8265874619836919]
# RMSE scores (CV): [297.2389007892064, 291.28387263317325, 262.38286698072653, 278.1530792089687, 273.3881037603326]
# Mean R²: 0.8492 ± 0.0171
# Mean RMSE: 280.49 ± 12.50
# Random Forest for mode: bus
# RMSE: 298.30
# R²: 0.8334
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 25, 'n_estimators': 200}
# R² scores (CV): [0.8172254830712692, 0.8232221158404645, 0.8234894186565809, 0.8384331497481565, 0.8092377741915299]
# RMSE scores (CV): [793.0850655058588, 804.6661931738646, 808.45717570099, 765.7540131237349, 726.8502379319955]
# Mean R²: 0.8223 ± 0.0096
# Mean RMSE: 779.76 ± 30.39
# Random Forest for mode: subway
# RMSE: 800.55
# R²: 0.8138

# %%
# Drop top 1 feature
df_no_weekend = NYC_df.drop(columns=['is_weekend'])
randforr(df_no_weekend)

# Drop top 2 features
df_no_weekend_holiday = NYC_df.drop(columns=['is_weekend', 'is_holiday'])
randforr(df_no_weekend_holiday)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 50}
# R² scores (CV): [0.02034440845284735, 0.047947961648986404, 0.06878579661469253, 0.06302900506751774, -0.038684948173183686]
# RMSE scores (CV): [723.4195435891014, 742.802954456479, 716.6459615351071, 709.8378665416761, 669.0849859495871]
# Mean R²: 0.0323 ± 0.0392
# Mean RMSE: 712.36 ± 24.28
# Random Forest for mode: bus
# RMSE: 712.13
# R²: 0.0507
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 100}
# R² scores (CV): [0.04532060213759004, 0.04859625570804549, 0.06712130517181614, 0.06267570574541692, -0.004135526795038924]
# RMSE scores (CV): [1812.5530428499626, 1866.7416519561932, 1858.592733258624, 1844.412636615733, 1667.6116206638007]
# Mean R²: 0.0439 ± 0.0254
# Mean RMSE: 1809.98 ± 73.55
# Random Forest for mode: subway
# RMSE: 1843.44
# R²: 0.0125
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 50}
# R² scores (CV): [0.011561999590801397, 0.036816852943787004, 0.04055131557636371, 0.051940248328086525, -0.034081194258251735]
# RMSE scores (CV): [726.6549615172861, 747.1326512394143, 727.4292129721404, 714.0258659099742, 667.6005495892396]
# Mean R²: 0.0214 ± 0.0307
# Mean RMSE: 716.57 ± 26.68
# Random Forest for mode: bus
# RMSE: 713.90
# R²: 0.0460
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 50}
# R² scores (CV): [0.02947023011494243, 0.04291323455542184, 0.02847341215134347, 0.030640923771596773, -0.026850281630806716]
# RMSE scores (CV): [1827.5378490604735, 1872.3086560851818, 1896.7015219185882, 1875.6659425722987, 1686.367833344757]
# Mean R²: 0.0209 ± 0.0245
# Mean RMSE: 1831.72 ± 76.09
# Random Forest for mode: subway
# RMSE: 1857.00
# R²: -0.0021
